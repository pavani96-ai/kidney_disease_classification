# %%
import os

# %%
# %pwd
# Out:
# '/mnt/d/dl_project/research'

# %%
os.chdir("../")
# %pwd
# Out:
# '/mnt/d/dl_project'

# %%
#download the data from gdrive
import gdown

# %%
url = "https://drive.google.com/file/d/19JqEboAL3nefYVfA-s4dMBkwlqZPTuYR/view?usp=sharing"

# %%
file_id = url.split("/")[-2]
file_id
# Out:
# '19JqEboAL3nefYVfA-s4dMBkwlqZPTuYR'

# %%
prefix = "https://drive.google.com/uc?export=download&id="
gdown.download(prefix+file_id, "CT-KIDNEY-DATASET-Normal-Cyst-Tumor-Stone.zip",quiet=False)
# Out:
# Downloading...
# From (original): https://drive.google.com/uc?id=19JqEboAL3nefYVfA-s4dMBkwlqZPTuYR
# From (redirected): https://drive.google.com/uc?id=19JqEboAL3nefYVfA-s4dMBkwlqZPTuYR&confirm=t&uuid=224a5f08-b98d-447e-92bf-45d68ff1534e
# To: /mnt/d/dl_project/CT-KIDNEY-DATASET-Normal-Cyst-Tumor-Stone.zip
# 100%|██████████| 1.63G/1.63G [05:59<00:00, 4.52MB/s]
# 'CT-KIDNEY-DATASET-Normal-Cyst-Tumor-Stone.zip'
